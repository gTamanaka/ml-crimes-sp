# %% [markdown]
# # Objetivo
# Desenvolver um modelo que possa inferir quando um crime possa ocorrer

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pandas as pd

# %% [markdown]
# ## Entradas
#
# Os dados disponivéis para análise são número do boletim de ocorrência(BO), o ano do BO, o identificador da delegacia, o nome do departamento, o nome da seccional, o nome da delegacia, o tipo de infração, o desdobramentos, conduta, latitude, longitude, logradouro e *status* da ocorrência.
# Para fins desse projeto apenas serão utilizados o número do boletim de ocorrência(BO), o ano do BO, o identificador da delegacia, o tipo de infração, o desdobramentos, latitude, longitude e *status* da ocorrência. Dessa forma eliminando a repetição de dados, como por exemplo o identificador único da delegacia já elimina a necessidade de ter o nome.
#
# Para as primeiras tentativas você serão utilizados apenas as ocorrências de 2016.
#
# Link para o dataset https://www.kaggle.com/inquisitivecrow/crime-data-in-brazil

# %%
bo_2016 = pd.read_csv("./data/BO_2016.csv")

print(bo_2016)
# Out:
# /home/tamanaka/Jupyter/ml/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          NUM_BO  ANO_BO  ID_DELEGACIA  \
# 0          3784    2016         10101
# 1          3426    2016         10102
# 2          6359    2016         10102
# 3          1267    2016         10103
# 4          4804    2016         10106
# 5          4609    2016         10105
# 6       1649798    2016        900020
# 7        393679    2016        900020
# 8        529372    2016        900020
# 9        560254    2016        900020
# 10       836504    2016        900020
# 11      1257647    2016        900020
# 12      1323403    2016        900020
# 13       839511    2016        900020
# 14         6997    2016        900020
# 15      1432118    2016        900020
# 16      1469698    2016        900020
# ...
